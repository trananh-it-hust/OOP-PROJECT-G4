# %%
from preprocess import preprocess_date, preprocess_text
import pandas as pd

# %%
relative_path = "../resources/data/data.csv"

sample_df = pd.read_csv(relative_path)

df = sample_df
df.head()
# Out:
#                                         Article link           Website source  \
# 0  https://www.theblock.co/post/285730/custodia-i...  https://www.theblock.co
# 1  https://www.theblock.co/post/285724/multicoin-...  https://www.theblock.co
# 2  https://www.theblock.co/post/285702/1kx-raise-...  https://www.theblock.co
# 3  https://www.theblock.co/post/285690/cftc-commi...  https://www.theblock.co
# 4  https://www.theblock.co/post/285608/bitcoin-fu...  https://www.theblock.co
#
#    Article type                                      Article title  \
# 0  News Article  Custodia is not entitled to a Fed master accou...
# 1  News Article  Multicoin Capital's hedge fund has grown 9,281...
# 2  News Article     1kx raises $75 million in latest funding round
# 3  News Article  CFTC Commissioner Pham says agency may be infr...
# 4  News Article  Bitcoin futures open interest reaches new high...
#
#                                              Content  \
# ...

# %%
df[' Article title'].apply(preprocess_text)
df[' Author'].apply(preprocess_text)
df[' Content'].apply(preprocess_text)
df[' Category'].apply(preprocess_text)

df.head(10)
# Out:
# d:\Program Files\Anaconda\Lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# d:\Program Files\Anaconda\Lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# 0       Custodia is not entitled to a Fed master accou...
# 1       Multicoin Capital's hedge fund has grown 9,281...
# 2          1kx raises $75 million in latest funding round
# 3       CFTC Commissioner Pham says agency may be infr...
# 4       Bitcoin futures open interest reaches new high...
# ...
